# %%
import pandas as pd

# %%
df=pd.read_csv('moviesDB.csv')

# %%
df
# Out:
#        movie                                             title  \
# 0     108583                               Fawlty Towers (1975
# 1      32898     Trip to the Moon, A (Voyage dans la lune, Le)
# 2       7065                            Birth of a Nation, The
# 3       7243  Intolerance: Love's Struggle Throughout the Ages
# 4      62383                      20,000 Leagues Under the Sea
# ...      ...                                               ...
# 9120  110748                                       Wake Wood (
# 9121  143410                                              Hyen
# 9122  151307                                The Lovers and the
# 9123  162376                                          Stranger
# 9124  164979                                   Women of '69, U
#
#                                genres  year  Rating  Rotton Tomato
# 0                              Comedy  1980       1             54
# 1     Action|Adventure|Fantasy|Sci-Fi  1902       7             80
# ...

# %%
df.head(10) #1st 10 rows
# Out:
#     movie                                              title  \
# 0  108583                                Fawlty Towers (1975
# 1   32898      Trip to the Moon, A (Voyage dans la lune, Le)
# 2    7065                             Birth of a Nation, The
# 3    7243   Intolerance: Love's Struggle Throughout the Ages
# 4   62383                       20,000 Leagues Under the Sea
# 5    8511                                     Immigrant, The
# 6    3309                                      Dog's Life, A
# 7   72626                                 Billy Blazes, Esq.
# 8    6987  Cabinet of Dr. Caligari, The (Cabinet des Dr. ...
# 9   25737    Golem, The (Golem, wie er in die Welt kam, Der)
#
#                             genres  year  Rating  Rotton Tomato
# 0                           Comedy  1980       1             54
# 1  Action|Adventure|Fantasy|Sci-Fi  1902       7             80
# 2                        Drama|War  1915       6             92
# ...

# %%
df.tail(10) #Last 10 rows
# Out:
#        movie                              title                genres  year  \
# 9115   89045                         Rocky VI (                Comedy  1922
# 9116   92206                 Hostel: Part III (       Horror|Thriller  1923
# 9117   94494                       96 Minutes (        Drama|Thriller  1924
# 9118  104595  Family Band: The Cowsills Story (           Documentary  1925
# 9119  108548             Big Bang Theory, The (                Comedy  1926
# 9120  110748                        Wake Wood (  Drama|Horror|Mystery  1927
# 9121  143410                               Hyen    (no genres listed)  1928
# 9122  151307                 The Lovers and the    (no genres listed)  1929
# 9123  162376                           Stranger                 Drama  1930
# 9124  164979                    Women of '69, U           Documentary  1931
#
#       Rating  Rotton Tomato
# 9115       5             64
# 9116       6             54
# 9117       3             94
# ...

# %%
df.head(-9000) #skips last 9000 rows
# Out:
#       movie                                             title  \
# 0    108583                               Fawlty Towers (1975
# 1     32898     Trip to the Moon, A (Voyage dans la lune, Le)
# 2      7065                            Birth of a Nation, The
# 3      7243  Intolerance: Love's Struggle Throughout the Ages
# 4     62383                      20,000 Leagues Under the Sea
# ..      ...                                               ...
# 120   39779                               Tarzan and His Mate
# 121   70121                          'Neath the Arizona Skies
# 122   98458                                   Baby Take a Bow
# 123   99270                               Stand Up and Cheer!
# 124     945                                           Top Hat
#
#                               genres  year  Rating  Rotton Tomato
# 0                             Comedy  1980       1             54
# 1    Action|Adventure|Fantasy|Sci-Fi  1902       7             80
# ...

# %%
df.columns # show me features and labels
# Out:
# Index(['movie', 'title', 'genres', 'year', 'Rating', 'Rotton Tomato'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9125 entries, 0 to 9124
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie          9125 non-null   int64
#  1   title          9125 non-null   object
#  2   genres         9125 non-null   object
#  3   year           9125 non-null   int64
#  4   Rating         9125 non-null   int64
#  5   Rotton Tomato  9125 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 427.9+ KB

# %%
moviesReleasePost1950=df[df['year']>1950]

# %%
moviesReleasePost1950
# Out:
#        movie                                              title  \
# 0     108583                                Fawlty Towers (1975
# 492      969                                 African Queen, The
# 493     1032                                Alice in Wonderland
# 499     3475                                Place in the Sun, A
# 500     3657                    Pandora and the Flying Dutchman
# ...      ...                                                ...
# 9108  161918                       Sharknado 4: The 4th Awakens
# 9109  162542                                             Rustom
# 9110  162672                                       Mohenjo Daro
# 9111  163056                                      Shin Godzilla
# 9112  163949  The Beatles: Eight Days a Week - The Touring Y...
#
#                                             genres  year  Rating  \
# 0                                           Comedy  1980       1
# ...

# %%
moviesReleasePost1950.shape
# Out:
# (8610, 6)

# %%
df.shape
# Out:
# (9125, 6)

# %%
df[(df['year']>1950) & (df['Rating']>8)]
# Out:
#        movie                                              title  \
# 499     3475                                Place in the Sun, A
# 507     8187                                   On Moonlight Bay
# 509     8502                                          Show Boat
# 518     2848  Othello (Tragedy of Othello: The Moor of Venic...
# 520     3314                                     Big Trees, The
# ...      ...                                                ...
# 9088  158783                                     The Handmaiden
# 9090  159093                                   Now You See Me 2
# 9094  159972                            Approaching the Unknown
# 9106  161582                                 Hell or High Water
# 9108  161918                       Sharknado 4: The 4th Awakens
#
#                               genres  year  Rating  Rotton Tomato
# 499                    Drama|Romance  1951      10             98
# ...

# %%
filtereddf=df[(df.year>1950) & (df.Rating>8)]

# %%
filtereddf
# Out:
#        movie                                              title  \
# 499     3475                                Place in the Sun, A
# 507     8187                                   On Moonlight Bay
# 509     8502                                          Show Boat
# 518     2848  Othello (Tragedy of Othello: The Moor of Venic...
# 520     3314                                     Big Trees, The
# ...      ...                                                ...
# 9088  158783                                     The Handmaiden
# 9090  159093                                   Now You See Me 2
# 9094  159972                            Approaching the Unknown
# 9106  161582                                 Hell or High Water
# 9108  161918                       Sharknado 4: The 4th Awakens
#
#                               genres  year  Rating  Rotton Tomato
# 499                    Drama|Romance  1951      10             98
# ...

# %%
df.isna().sum() # check for null values
# Out:
# movie            0
# title            0
# genres           0
# year             0
# Rating           0
# Rotton Tomato    0
# dtype: int64

# %%
df.isna().any()
# Out:
# movie            False
# title            False
# genres           False
# year             False
# Rating           False
# Rotton Tomato    False
# dtype: bool

# %%
df.isna()
# Out:
#       movie  title  genres   year  Rating  Rotton Tomato
# 0     False  False   False  False   False          False
# 1     False  False   False  False   False          False
# 2     False  False   False  False   False          False
# 3     False  False   False  False   False          False
# 4     False  False   False  False   False          False
# ...     ...    ...     ...    ...     ...            ...
# 9120  False  False   False  False   False          False
# 9121  False  False   False  False   False          False
# 9122  False  False   False  False   False          False
# 9123  False  False   False  False   False          False
# 9124  False  False   False  False   False          False
#
# [9125 rows x 6 columns]

# %%
df.isnull()
# Out:
#       movie  title  genres   year  Rating  Rotton Tomato
# 0     False  False   False  False   False          False
# 1     False  False   False  False   False          False
# 2     False  False   False  False   False          False
# 3     False  False   False  False   False          False
# 4     False  False   False  False   False          False
# ...     ...    ...     ...    ...     ...            ...
# 9120  False  False   False  False   False          False
# 9121  False  False   False  False   False          False
# 9122  False  False   False  False   False          False
# 9123  False  False   False  False   False          False
# 9124  False  False   False  False   False          False
#
# [9125 rows x 6 columns]

# %%
sortedf=df.sort_values("Rotton Tomato",ascending=False)

# %%
sortedf
# Out:
#        movie                                            title  \
# 7479   91610                                  Toronto Stories
# 7405   64957             Curious Case of Benjamin Button, The
# 7471   79136                                           Thirst
# 7464   74486                                           $9.99
# 2958    4662                        See No Evil, Hear No Evil
# ...      ...                                              ...
# 2700    2245                                     Working Girl
# 1201   26188                    Heart Is a Lonely Hunter, The
# 8564  106642                           Day of the Doctor, The
# 6207   27700                                   Evil (Ondskan)
# 6135    6947  Master and Commander: The Far Side of the World
#
#                              genres  year  Rating  Rotton Tomato
# 7479                          Drama  2007       4            100
# 7405  Drama|Fantasy|Mystery|Romance  2008       3            100
# ...

# %%
df["Movie Rank"]=df["Rotton Tomato"].rank(ascending=False).astype("int")

# %%
df.sort_values("Movie Rank",ascending=True)
# Out:
#       movie                                              title  \
# 3460    469                          House of the Spirits, The
# 5647   5095                                      Scotland, Pa.
# 4850   2441                                 Hi-Lo Country, The
# 6139   6953                                           21 Grams
# 7889  81949                                     Romantics, The
# ...     ...                                                ...
# 2100   1389                                           Jaws 3-D
# 2098   1289  Koyaanisqatsi (a.k.a. Koyaanisqatsi: Life Out ...
# 6151   7152                                     Statement, The
# 7167  56941                                    P.S. I Love You
# 4130     74                                       Bed of Roses
#
#                                     genres  year  Rating  Rotton Tomato  \
# 3460                         Drama|Romance  1993       8            100
# ...

# %%
sortedf
# Out:
#        movie                                            title  \
# 7479   91610                                  Toronto Stories
# 7405   64957             Curious Case of Benjamin Button, The
# 7471   79136                                           Thirst
# 7464   74486                                           $9.99
# 2958    4662                        See No Evil, Hear No Evil
# ...      ...                                              ...
# 2700    2245                                     Working Girl
# 1201   26188                    Heart Is a Lonely Hunter, The
# 8564  106642                           Day of the Doctor, The
# 6207   27700                                   Evil (Ondskan)
# 6135    6947  Master and Commander: The Far Side of the World
#
#                              genres  year  Rating  Rotton Tomato
# 7479                          Drama  2007       4            100
# 7405  Drama|Fantasy|Mystery|Romance  2008       3            100
# ...

# %%
df[df['Movie Rank']>100]
# Out:
#        movie                                             title  \
# 0     108583                               Fawlty Towers (1975
# 1      32898     Trip to the Moon, A (Voyage dans la lune, Le)
# 2       7065                            Birth of a Nation, The
# 3       7243  Intolerance: Love's Struggle Throughout the Ages
# 4      62383                      20,000 Leagues Under the Sea
# ...      ...                                               ...
# 9120  110748                                       Wake Wood (
# 9121  143410                                              Hyen
# 9122  151307                                The Lovers and the
# 9123  162376                                          Stranger
# 9124  164979                                   Women of '69, U
#
#                                genres  year  Rating  Rotton Tomato  Movie Rank
# 0                              Comedy  1980       1             54        8309
# ...

# %%
groupdf=df.groupby('genres')  #group by clause
groupdf.mean('Rating')
# Out:
#                                              movie         year    Rating  \
# genres
# (no genres listed)                   133380.000000  1998.166667  6.555556
# Action                                23427.179487  1993.282051  5.717949
# Action|Adventure                      34647.656250  1987.125000  5.468750
# Action|Adventure|Animation           102695.928571  1999.714286  5.571429
# Action|Adventure|Animation|Children   99468.000000  1998.000000  6.333333
# ...                                            ...          ...       ...
# Sci-Fi|Thriller                       34915.153846  1992.461538  4.461538
# Sci-Fi|Thriller|IMAX                  89470.000000  2010.000000  5.000000
# Thriller                              33945.418919  1995.486486  5.310811
# War                                    3845.500000  1970.666667  5.500000
# Western                               16038.645161  1970.838710  6.322581
#
#                                      Rotton Tomato   Movie Rank
# ...
